# %%
historyGlobal = None
def plot_history(history):
  acc = history.history['accuracy']
  loss = history.history['loss']

  epochs = range(len(acc))

  plt.figure()
  plt.plot(epochs, acc, 'bo', label='Training acc')
  plt.legend()

  plt.figure()
  plt.plot(epochs, loss, 'bo', label='Training loss')
  plt.legend()

  plt.show()

def train_model(model,epochs=25):
  history = model.fit(
      train_generator,
      steps_per_epoch=100,
      epochs=epochs,
      #validation_data=valid_generator,
      validation_steps=100, callbacks=[])
  global historyGlobal
  historyGlobal = history
  plot_history(history)

# %%
file_path = "/content/drive/MyDrive/SP2021/4390/Images_sorted"
file_train = "/content/drive/MyDrive/SP2021/4390/images_sorted2/Training"
file_test = "/content/drive/MyDrive/SP2021/4390/images_sorted2/Testing"

file_train = "/content/drive/MyDrive/SP2021/4390/images_sorted_x256"

#Local copies

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
my_generator = ImageDataGenerator(rescale=1./255)

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=10,
    brightness_range=[0.8,1.2],
    fill_mode='nearest'
    )

validate_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=10,
    brightness_range=[0.8,1.2],
    fill_mode='nearest'
    )
train_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory( file_train, target_size=(256, 256), batch_size=16, class_mode='binary')
#valid_generator = validate_datagen.flow_from_directory(file_test, target_size=(256, 256), batch_size=16, class_mode='binary')
# Out:
# Found 2669 images belonging to 2 classes.

# %%
import matplotlib.pyplot as plt
import numpy as np
itor = 0
for my_batch in train_generator:
    # my_batch is a tuple with images and labels
    images = my_batch[0]
    labels = my_batch[1]
    for i in range(len(labels)):
        # Gives one image and its corresponding label
        #plt.imshow(images[i])
        plt.imshow(images[i])
        plt.colorbar()
        plt.show()
        print(images[i].shape)
        print(labels[i])
        break
    if itor > 3: break
    itor+=1
# Out:
# (256, 256, 3)
# 1.0
# (256, 256, 3)
# 1.0
# (256, 256, 3)
# 0.0
# (256, 256, 3)
# 0.0
# (256, 256, 3)
# 1.0

# %% [markdown]
# Build a model:

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
import matplotlib.pyplot as plt

# %%
model = Sequential()
model.add(Conv2D(filters = 64, kernel_size = 3, activation = 'relu', input_shape = (256, 256, 3)))
model.add(Conv2D(filters = 8, kernel_size = 3, activation = 'relu'))
model.add(Conv2D(filters = 8, kernel_size = 3, activation = 'relu'))
model.add(Conv2D(filters = 8, kernel_size = 3, activation = 'relu'))
model.add(MaxPooling2D(pool_size = 8, strides = 8))
model.add(Flatten())
model.add(Dense(units = 16, activation = 'relu'))
model.add( Dense( 1, activation = 'sigmoid' ) )
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
print(model.summary())
train_model(model,epochs=50)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 254, 254, 64)      1792
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 252, 252, 8)       4616
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 250, 250, 8)       584
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 248, 248, 8)       584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 31, 31, 8)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7688)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                123024
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 130,617
# Trainable params: 130,617
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 100/100 [==============================] - 454s 5s/step - loss: 0.6778 - accuracy: 0.5595
# Epoch 2/50
# 100/100 [==============================] - 166s 2s/step - loss: 0.5044 - accuracy: 0.7763
# Epoch 3/50
# 100/100 [==============================] - 70s 708ms/step - loss: 0.3654 - accuracy: 0.8425
# Epoch 4/50
# 100/100 [==============================] - 30s 303ms/step - loss: 0.3200 - accuracy: 0.8648
# Epoch 5/50
# 100/100 [==============================] - 17s 174ms/step - loss: 0.2935 - accuracy: 0.8927
# Epoch 6/50
# 100/100 [==============================] - 10s 99ms/step - loss: 0.2786 - accuracy: 0.8898
# Epoch 7/50
# 100/100 [==============================] - 9s 86ms/step - loss: 0.2345 - accuracy: 0.9067
# Epoch 8/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.2022 - accuracy: 0.9300
# Epoch 9/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.2266 - accuracy: 0.9167
# Epoch 10/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.1855 - accuracy: 0.9371
# Epoch 11/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1868 - accuracy: 0.9357
# Epoch 12/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1963 - accuracy: 0.9349
# Epoch 13/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1319 - accuracy: 0.9493
# Epoch 14/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1198 - accuracy: 0.9578
# Epoch 15/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0879 - accuracy: 0.9711
# Epoch 16/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0953 - accuracy: 0.9759
# Epoch 17/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0711 - accuracy: 0.9807
# Epoch 18/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0893 - accuracy: 0.9746
# Epoch 19/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0741 - accuracy: 0.9739
# Epoch 20/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0679 - accuracy: 0.9690
# Epoch 21/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0464 - accuracy: 0.9888
# Epoch 22/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0477 - accuracy: 0.9886
# Epoch 23/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0464 - accuracy: 0.9888
# Epoch 24/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0469 - accuracy: 0.9820
# Epoch 25/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0372 - accuracy: 0.9874
# Epoch 26/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0283 - accuracy: 0.9929
# Epoch 27/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0241 - accuracy: 0.9922
# Epoch 28/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0840 - accuracy: 0.9687
# Epoch 29/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0277 - accuracy: 0.9893
# Epoch 30/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0191 - accuracy: 0.9956
# Epoch 31/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0123 - accuracy: 0.9972
# Epoch 32/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0195 - accuracy: 0.9946
# Epoch 33/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0150 - accuracy: 0.9967
# Epoch 34/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0089 - accuracy: 0.9978
# Epoch 35/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0156 - accuracy: 0.9942
# Epoch 36/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0658 - accuracy: 0.9791
# Epoch 37/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.0173 - accuracy: 0.9954
# Epoch 38/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0200 - accuracy: 0.9939
# Epoch 39/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0202 - accuracy: 0.9938
# Epoch 40/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0123 - accuracy: 0.9968
# Epoch 41/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 42/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0067 - accuracy: 0.9979
# Epoch 43/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0022 - accuracy: 0.9995
# Epoch 44/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0033 - accuracy: 0.9981
# Epoch 45/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 46/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0025 - accuracy: 0.9991
# Epoch 47/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0028 - accuracy: 0.9988
# Epoch 48/50
# 100/100 [==============================] - 6s 64ms/step - loss: 8.7409e-04 - accuracy: 1.0000
# Epoch 49/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0026 - accuracy: 0.9994
# Epoch 50/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0014 - accuracy: 0.9998

# %%
model = Sequential()
model.add(Conv2D(filters = 64, kernel_size = 3, activation = 'relu', input_shape = (256, 256, 3)))
#model.add(MaxPooling2D(pool_size = 2, strides = 2))
model.add(Conv2D(filters = 8, kernel_size = 3, activation = 'relu'))
model.add(Conv2D(filters = 8, kernel_size = 3, activation = 'relu'))
model.add(Conv2D(filters = 8, kernel_size = 3, activation = 'relu'))
model.add(MaxPooling2D(pool_size = 2, strides = 2))
model.add(Flatten())
model.add(Dense(units = 16, activation = 'relu'))
model.add( Dense( 1, activation = 'sigmoid' ) )
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
print(model.summary())
train_model(model,epochs=50)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 254, 254, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 125, 125, 16)      9232
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 123, 123, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 61, 61, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 59536)             0
# _________________________________________________________________
# dense (Dense)                (None, 16)                952592
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 965,953
# Trainable params: 965,953
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 100/100 [==============================] - 283s 3s/step - loss: 0.7921 - accuracy: 0.4700 - val_loss: 0.6915 - val_accuracy: 0.5550
# Epoch 2/50
# 100/100 [==============================] - 189s 2s/step - loss: 0.6900 - accuracy: 0.5950 - val_loss: 0.6903 - val_accuracy: 0.5800
# Epoch 3/50
# 100/100 [==============================] - 142s 1s/step - loss: 0.6977 - accuracy: 0.5898 - val_loss: 0.6895 - val_accuracy: 0.5950
# Epoch 4/50
# 100/100 [==============================] - 137s 1s/step - loss: 0.6945 - accuracy: 0.4837 - val_loss: 0.6908 - val_accuracy: 0.5500
# Epoch 5/50
# 100/100 [==============================] - 122s 1s/step - loss: 0.6928 - accuracy: 0.5149 - val_loss: 0.6897 - val_accuracy: 0.5750
# Epoch 6/50
# 100/100 [==============================] - 110s 1s/step - loss: 0.7142 - accuracy: 0.5672 - val_loss: 0.6883 - val_accuracy: 0.5800
# Epoch 7/50
# 100/100 [==============================] - 85s 847ms/step - loss: 0.6864 - accuracy: 0.6025 - val_loss: 0.6884 - val_accuracy: 0.5800
# Epoch 8/50
# 100/100 [==============================] - 92s 923ms/step - loss: 0.6899 - accuracy: 0.5590 - val_loss: 0.6884 - val_accuracy: 0.5750
# Epoch 9/50
# 100/100 [==============================] - 78s 773ms/step - loss: 0.6856 - accuracy: 0.6058 - val_loss: 0.6862 - val_accuracy: 0.5850
# Epoch 10/50
# 100/100 [==============================] - 83s 829ms/step - loss: 0.6785 - accuracy: 0.6537 - val_loss: 0.6868 - val_accuracy: 0.5650
# Epoch 11/50
# 100/100 [==============================] - 70s 701ms/step - loss: 0.6838 - accuracy: 0.5886 - val_loss: 0.6886 - val_accuracy: 0.5500
# Epoch 12/50
# 100/100 [==============================] - 70s 703ms/step - loss: 0.6881 - accuracy: 0.5530 - val_loss: 0.6821 - val_accuracy: 0.5900
# Epoch 13/50
# 100/100 [==============================] - 78s 791ms/step - loss: 0.6880 - accuracy: 0.5522 - val_loss: 0.6832 - val_accuracy: 0.5800
# Epoch 14/50
# 100/100 [==============================] - 66s 655ms/step - loss: 0.6660 - accuracy: 0.6786 - val_loss: 0.6939 - val_accuracy: 0.5200
# Epoch 15/50
# 100/100 [==============================] - 62s 628ms/step - loss: 0.6778 - accuracy: 0.6020 - val_loss: 0.6882 - val_accuracy: 0.5500
# Epoch 16/50
# 100/100 [==============================] - 59s 594ms/step - loss: 0.6697 - accuracy: 0.6339 - val_loss: 0.6848 - val_accuracy: 0.5650
# Epoch 17/50
# 100/100 [==============================] - 54s 547ms/step - loss: 0.6771 - accuracy: 0.5970 - val_loss: 0.6859 - val_accuracy: 0.5600
# Epoch 18/50
# 100/100 [==============================] - 50s 505ms/step - loss: 0.6798 - accuracy: 0.5854 - val_loss: 0.6822 - val_accuracy: 0.5750
# Epoch 19/50
# 100/100 [==============================] - 49s 489ms/step - loss: 0.6677 - accuracy: 0.6332 - val_loss: 0.6808 - val_accuracy: 0.5800
# Epoch 20/50
# 100/100 [==============================] - 50s 506ms/step - loss: 0.6828 - accuracy: 0.5727 - val_loss: 0.6859 - val_accuracy: 0.5600
# Epoch 21/50
# 100/100 [==============================] - 43s 434ms/step - loss: 0.6788 - accuracy: 0.5888 - val_loss: 0.6736 - val_accuracy: 0.6100
# Epoch 22/50
# 100/100 [==============================] - 43s 430ms/step - loss: 0.6813 - accuracy: 0.5788 - val_loss: 0.6795 - val_accuracy: 0.5850
# Epoch 23/50
# 100/100 [==============================] - 33s 331ms/step - loss: 0.6983 - accuracy: 0.5126 - val_loss: 0.6807 - val_accuracy: 0.5800
# Epoch 24/50
# 100/100 [==============================] - 39s 392ms/step - loss: 0.6888 - accuracy: 0.5498 - val_loss: 0.6979 - val_accuracy: 0.5150
# Epoch 25/50
# 100/100 [==============================] - 43s 424ms/step - loss: 0.6736 - accuracy: 0.6068 - val_loss: 0.6791 - val_accuracy: 0.5850
# Epoch 26/50
# 100/100 [==============================] - 37s 374ms/step - loss: 0.6841 - accuracy: 0.5676 - val_loss: 0.6944 - val_accuracy: 0.5300
# Epoch 27/50
# 100/100 [==============================] - 42s 420ms/step - loss: 0.6718 - accuracy: 0.6111 - val_loss: 0.6906 - val_accuracy: 0.5450
# Epoch 28/50
# 100/100 [==============================] - 36s 358ms/step - loss: 0.6832 - accuracy: 0.5707 - val_loss: 0.6746 - val_accuracy: 0.6000
# Epoch 29/50
# 100/100 [==============================] - 34s 333ms/step - loss: 0.6877 - accuracy: 0.5546 - val_loss: 0.6875 - val_accuracy: 0.5550
# Epoch 30/50
# 100/100 [==============================] - 32s 325ms/step - loss: 0.6645 - accuracy: 0.6373 - val_loss: 0.6718 - val_accuracy: 0.6100
# Epoch 31/50
# 100/100 [==============================] - 31s 303ms/step - loss: 0.6907 - accuracy: 0.5446 - val_loss: 0.6701 - val_accuracy: 0.6150
# Epoch 32/50
# 100/100 [==============================] - 32s 313ms/step - loss: 0.6874 - accuracy: 0.5563 - val_loss: 0.6789 - val_accuracy: 0.5850
# Epoch 33/50
# 100/100 [==============================] - 30s 298ms/step - loss: 0.6991 - accuracy: 0.5165 - val_loss: 0.6761 - val_accuracy: 0.5950
# Epoch 34/50
# 100/100 [==============================] - 31s 307ms/step - loss: 0.6676 - accuracy: 0.6247 - val_loss: 0.6789 - val_accuracy: 0.5850
# Epoch 35/50
# 100/100 [==============================] - 32s 324ms/step - loss: 0.6715 - accuracy: 0.6103 - val_loss: 0.6760 - val_accuracy: 0.5950
# Epoch 36/50
# 100/100 [==============================] - 29s 296ms/step - loss: 0.6508 - accuracy: 0.6814 - val_loss: 0.6834 - val_accuracy: 0.5700
# Epoch 37/50
# 100/100 [==============================] - 30s 299ms/step - loss: 0.6655 - accuracy: 0.6298 - val_loss: 0.6849 - val_accuracy: 0.5650
# Epoch 38/50
# 100/100 [==============================] - 28s 277ms/step - loss: 0.6498 - accuracy: 0.6803 - val_loss: 0.6849 - val_accuracy: 0.5650
# Epoch 39/50
# 100/100 [==============================] - 29s 292ms/step - loss: 0.6695 - accuracy: 0.6152 - val_loss: 0.6849 - val_accuracy: 0.5650
# Epoch 40/50
# 100/100 [==============================] - 29s 294ms/step - loss: 0.7029 - accuracy: 0.5062 - val_loss: 0.6773 - val_accuracy: 0.5900
# Epoch 41/50
# 100/100 [==============================] - 29s 295ms/step - loss: 0.6866 - accuracy: 0.5598 - val_loss: 0.6819 - val_accuracy: 0.5750
# Epoch 42/50
# 100/100 [==============================] - 26s 264ms/step - loss: 0.6712 - accuracy: 0.6095 - val_loss: 0.6772 - val_accuracy: 0.5900
# Epoch 43/50
# 100/100 [==============================] - 28s 277ms/step - loss: 0.6612 - accuracy: 0.6408 - val_loss: 0.6787 - val_accuracy: 0.5850
# Epoch 44/50
# 100/100 [==============================] - 26s 262ms/step - loss: 0.6890 - accuracy: 0.5528 - val_loss: 0.6868 - val_accuracy: 0.5600
# Epoch 45/50
# 100/100 [==============================] - 27s 272ms/step - loss: 0.6763 - accuracy: 0.5927 - val_loss: 0.6917 - val_accuracy: 0.5450
# Epoch 46/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.6888 - accuracy: 0.5536 - val_loss: 0.6958 - val_accuracy: 0.5300
# Epoch 47/50
# 100/100 [==============================] - 26s 259ms/step - loss: 0.6714 - accuracy: 0.6090 - val_loss: 0.6866 - val_accuracy: 0.5600
# Epoch 48/50
# 100/100 [==============================] - 26s 257ms/step - loss: 0.6608 - accuracy: 0.6422 - val_loss: 0.6851 - val_accuracy: 0.5650
# Epoch 49/50
# 100/100 [==============================] - 24s 243ms/step - loss: 0.6776 - accuracy: 0.5885 - val_loss: 0.6900 - val_accuracy: 0.5500
# Epoch 50/50
# 100/100 [==============================] - 25s 248ms/step - loss: 0.6700 - accuracy: 0.6122 - val_loss: 0.6883 - val_accuracy: 0.5550
